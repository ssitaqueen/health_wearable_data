# %% [markdown]
# # 1. 데이터셋 불러오기 & 확인하기

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("orvile/wesad-wearable-stress-affect-detection-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\sunja\.cache\kagglehub\datasets\orvile\wesad-wearable-stress-affect-detection-dataset\1.archive...
# 100%|██████████| 2.43G/2.43G [02:11<00:00, 19.9MB/s]
# Extracting files...
# Path to dataset files: C:\Users\sunja\.cache\kagglehub\datasets\orvile\wesad-wearable-stress-affect-detection-dataset\versions\1
